# %% [markdown]
# # explore badges

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.read_csv('data/stats/csv/badges.csv')

# %%
df.head()
# Out:
#    Id  UserId     Name                     Date  Class  TagBased
# 0   1       5  Teacher  2010-07-19T19:39:07.047      3     False
# 1   2       6  Teacher  2010-07-19T19:39:07.220      3     False
# 2   3       8  Teacher  2010-07-19T19:39:07.330      3     False
# 3   4      23  Teacher  2010-07-19T19:39:07.437      3     False
# 4   5      36  Teacher  2010-07-19T19:39:07.593      3     False

# %%
df.Id.value_counts().plot()

# %%
df.Name.value_counts()
# Out:
# Student                55499
# Autobiographer         48112
# Editor                 39593
# Supporter              39359
# Popular Question       33529
#                        ...
# boxplot                    1
# mgf                        1
# importance-sampling        1
# survey                     1
# boosting                   1
# Name: Name, Length: 327, dtype: int64

# %%
df.Name.value_counts().plot()
